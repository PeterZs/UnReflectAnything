# %%
from PIL import Image
import numpy as np
import os
import sys

sys.path.append("/home/alberto/UnReflectAnything/")
from utilities.visualization import rgb, panelize
import torch
from dataset.scrream import SCRREAM
from rich import print
# %load_ext autoreload
# %autoreload 2

# %%
from datasets import load_dataset
ds = load_dataset("Mingde/PolaRGB")
# Out:
# train/easy/input/17/0033_rgb.png:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# train/easy/input/17/0034_000.png:   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# train/easy/input/17/0034_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0034_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0034_135.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0035_045.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0034_rgb.png:   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/easy/input/17/0035_000.png:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# train/easy/input/17/0036_000.png:   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# train/easy/input/17/0035_090.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0036_045.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0035_rgb.png:   0%|          | 0.00/1.88M [00:00<?, ?B/s]
# train/easy/input/17/0036_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0035_135.png:   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# train/easy/input/17/0036_rgb.png:   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/easy/input/17/0036_135.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0037_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0037_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0037_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0037_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0037_045.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0038_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0038_000.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0038_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0038_rgb.png:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/easy/input/17/0038_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0039_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0039_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0039_000.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0040_000.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0039_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0039_rgb.png:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# train/easy/input/17/0040_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0040_045.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0041_000.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0040_rgb.png:   0%|          | 0.00/1.83M [00:00<?, ?B/s]
# train/easy/input/17/0040_135.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0041_045.png:   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# train/easy/input/17/0041_090.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0041_135.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0041_rgb.png:   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/easy/input/17/0042_000.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0042_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0042_045.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0042_090.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0043_000.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0043_045.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0042_rgb.png:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# train/easy/input/17/0043_090.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0043_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0043_rgb.png:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# train/easy/input/17/0044_000.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0044_045.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0044_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0044_135.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0044_rgb.png:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# train/easy/input/17/0045_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0045_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0045_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0045_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0045_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0046_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0046_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0046_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0047_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0046_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0046_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0047_045.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0047_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0047_135.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0048_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0048_045.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0048_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0047_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0048_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0048_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0049_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0049_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0049_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0049_000.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0049_rgb.png:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/easy/input/17/0050_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0050_000.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0050_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0050_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0050_rgb.png:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/easy/input/17/0051_000.png:   0%|          | 0.00/2.05M [00:00<?, ?B/s]
# train/easy/input/17/0051_rgb.png:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# train/easy/input/17/0051_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0051_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0051_135.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0052_000.png:   0%|          | 0.00/2.04M [00:00<?, ?B/s]
# train/easy/input/17/0052_045.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0052_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0052_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0053_000.png:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# train/easy/input/17/0052_rgb.png:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# train/easy/input/17/0053_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0053_045.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0053_135.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0053_rgb.png:   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/easy/input/17/0054_045.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0054_rgb.png:   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# train/easy/input/17/0055_000.png:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# train/easy/input/17/0054_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0054_135.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0055_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0054_000.png:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# train/easy/input/17/0055_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0056_000.png:   0%|          | 0.00/2.05M [00:00<?, ?B/s]
# train/easy/input/17/0056_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0055_rgb.png:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# train/easy/input/17/0055_135.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0056_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0056_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0056_rgb.png:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# train/easy/input/17/0057_000.png:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# train/easy/input/17/0057_045.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0057_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0057_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0057_rgb.png:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# train/easy/input/17/0058_000.png:   0%|          | 0.00/2.05M [00:00<?, ?B/s]
# train/easy/input/17/0058_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0058_045.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0058_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0058_rgb.png:   0%|          | 0.00/1.83M [00:00<?, ?B/s]
# train/easy/input/17/0059_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0059_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0059_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0059_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0060_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0060_045.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0059_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0060_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0060_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0060_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0061_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0061_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0061_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0061_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0061_135.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0062_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0062_000.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0062_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0062_135.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0062_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0063_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0063_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0063_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0063_rgb.png:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# train/easy/input/17/0063_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0064_000.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0064_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0064_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0064_rgb.png:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/easy/input/17/0065_000.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0064_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0065_045.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0065_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0066_000.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0066_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0066_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0066_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0065_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0067_000.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0066_rgb.png:   0%|          | 0.00/1.83M [00:00<?, ?B/s]
# train/easy/input/17/0067_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0065_rgb.png:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/easy/input/17/0067_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0067_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0067_rgb.png:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# train/easy/input/17/0068_000.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0068_045.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0068_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0068_090.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0068_rgb.png:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# train/easy/input/17/0069_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0069_000.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0069_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0070_000.png:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# train/easy/input/17/0070_135.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0069_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0070_090.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0070_045.png:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# train/easy/input/17/0069_rgb.png:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# train/easy/input/17/0070_rgb.png:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# train/easy/input/17/0071_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0071_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0071_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0071_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0071_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0072_000.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0072_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0072_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0072_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0073_000.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0073_045.png:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# train/easy/input/17/0072_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0073_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0073_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0073_rgb.png:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# train/easy/input/17/0074_000.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0074_135.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0074_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0074_045.png:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# train/easy/input/17/0075_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0075_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0075_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0075_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0074_rgb.png:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# train/easy/input/17/0075_rgb.png:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# train/easy/input/17/0076_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0076_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0076_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0076_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0076_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0077_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0077_045.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0077_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0077_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0077_135.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0078_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0078_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0078_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0078_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0078_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0079_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0079_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0080_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0079_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0079_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0079_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0080_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0080_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0080_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0080_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0081_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0081_090.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0081_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0081_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0081_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0082_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0082_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0082_090.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0082_135.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0082_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0083_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0083_090.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0083_045.png:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# train/easy/input/17/0083_135.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0084_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0084_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0083_rgb.png:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# train/easy/input/17/0084_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0084_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0085_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0084_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0085_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0085_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0085_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0085_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0086_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0086_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0086_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0086_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0086_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0087_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0087_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0087_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0088_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0087_rgb.png:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# train/easy/input/17/0088_090.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0089_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0088_rgb.png:   0%|          | 0.00/1.78M [00:00<?, ?B/s]
# train/easy/input/17/0087_000.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0088_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0089_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0088_135.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0089_rgb.png:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# train/easy/input/17/0089_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0090_000.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0089_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0090_135.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/17/0091_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0090_090.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0091_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0090_rgb.png:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# train/easy/input/17/0091_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0092_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0090_045.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/17/0091_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0091_rgb.png:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# train/easy/input/17/0092_090.png:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# train/easy/input/17/0092_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0092_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0092_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0093_000.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0093_045.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0093_090.png:   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# train/easy/input/17/0094_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0093_rgb.png:   0%|          | 0.00/1.74M [00:00<?, ?B/s]
# train/easy/input/17/0094_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0094_090.png:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# train/easy/input/17/0094_135.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0093_135.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0094_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0095_000.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0095_090.png:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# train/easy/input/17/0095_135.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0095_045.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0096_000.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0095_rgb.png:   0%|          | 0.00/1.74M [00:00<?, ?B/s]
# train/easy/input/17/0096_045.png:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# train/easy/input/17/0097_000.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0096_rgb.png:   0%|          | 0.00/1.73M [00:00<?, ?B/s]
# train/easy/input/17/0096_090.png:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# train/easy/input/17/0096_135.png:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# train/easy/input/17/0097_090.png:   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# train/easy/input/17/0097_045.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0097_135.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0098_000.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0097_rgb.png:   0%|          | 0.00/1.75M [00:00<?, ?B/s]
# train/easy/input/17/0099_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0098_045.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0098_135.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0098_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0098_090.png:   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# train/easy/input/17/0099_090.png:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# train/easy/input/17/0099_045.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0099_rgb.png:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# train/easy/input/17/0100_000.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0099_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0100_045.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0100_135.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0100_rgb.png:   0%|          | 0.00/1.75M [00:00<?, ?B/s]
# train/easy/input/17/0101_045.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0101_000.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0100_090.png:   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# train/easy/input/17/0101_135.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/17/0101_090.png:   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# train/easy/input/17/0102_045.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0101_rgb.png:   0%|          | 0.00/1.75M [00:00<?, ?B/s]
# train/easy/input/17/0102_000.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0102_135.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/17/0102_090.png:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# train/easy/input/17/0102_rgb.png:   0%|          | 0.00/1.76M [00:00<?, ?B/s]
# train/easy/input/17/0103_000.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0103_045.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0103_135.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/17/0103_rgb.png:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# train/easy/input/17/0103_090.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/18/0000_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0000_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0000_135.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0001_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0000_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0000_rgb.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/18/0001_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0001_rgb.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/18/0001_045.png:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# train/easy/input/18/0002_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0002_000.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0002_rgb.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/18/0002_135.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0002_090.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0001_135.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0004_000.png:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# train/easy/input/18/0003_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0003_045.png:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# train/easy/input/18/0003_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0003_135.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0004_045.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0004_090.png:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# train/easy/input/18/0003_rgb.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/18/0004_135.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0005_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0004_rgb.png:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# train/easy/input/18/0005_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0005_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0005_135.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0005_rgb.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/18/0006_000.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0006_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0006_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0006_135.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0006_rgb.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/18/0007_000.png:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# train/easy/input/18/0007_045.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0007_090.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0007_rgb.png:   0%|          | 0.00/1.97M [00:00<?, ?B/s]
# train/easy/input/18/0007_135.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0008_000.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0008_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0008_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0008_135.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0009_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0008_rgb.png:   0%|          | 0.00/1.95M [00:00<?, ?B/s]
# train/easy/input/18/0009_045.png:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# train/easy/input/18/0010_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0009_090.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0009_rgb.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/18/0009_135.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0010_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0010_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0010_135.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0010_rgb.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# train/easy/input/18/0011_000.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0011_045.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0011_090.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0011_135.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0011_rgb.png:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# train/easy/input/18/0012_135.png:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# train/easy/input/18/0012_090.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0012_045.png:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# train/easy/input/18/0012_000.png:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# train/easy/input/18/0013_000.png:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# train/easy/input/18/0012_rgb.png:   0%|          | 0.00/1.94M [00:00<?, ?B/s]

# %%
ds

# %%
dataset = SCRREAM(
        root_dir="/datasets/SCRREAM/",
        scene_names=["scene01_full_00"],
        rho_s=0.6,
        eps=1e-8
    )
    
# Create dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True)
idataloade = iter(dataloader)

# Test loading a batch
for batch in dataloader:
    # print("Batch shapes:")
    # for key, tensor in batch.items():
    #     print(f"  {key}: {tensor.shape}")  # All will be [B, C, H, W]

    
    break

# rgb(batch["rgb"][0],colormap="hsv")

# %%
rgb(
    panelize(
        rgb(
            batch["rgb"][0],
            as_tensor=True,
            resize=(892, 1140),
            colormap="gray",
        ),
        panelize(
        panelize(
            rgb(
                0.2 * batch["specular"][0] + 0.8 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
            rgb(
                0.4 * batch["specular"][0] + 0.6 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
            rgb(
                0.6 * batch["specular"][0] + 0.4 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
            rgb(
                0.8 * batch["specular"][0] + 0.2 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
        ),
        panelize(
            rgb(
                0.8 * batch["specular"][0] + 0.2 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
            rgb(
                0.6 * batch["specular"][0] + 0.4 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
            rgb(
                0.4 * batch["specular"][0] + 0.6 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
            rgb(
                0.2 * batch["specular"][0] + 0.8 * batch["diffuse"][0],
                as_tensor=True,
                resize=(892 // 2, 1140 // 2),
            ),
        ),
        mode="vertical"),
        resize_to_match=False
    )
)

# %%
from projections import ReflectionWarp
from dotmap import DotMap
import yaml

# Initialize the module
height, width = batch["rgb"].shape[2:]
reflection_warp = ReflectionWarp(height, width)
reflection_warp = reflection_warp.cuda()  # Move to GPU


light_color = torch.tensor([1.0, 0.8, 0.8]).cuda()  # Warm light

from pipelines.depth.depth import DepthPipeline

CONFIG_PATH = "../config.yaml"
with open(CONFIG_PATH, "r") as f:
    config_yaml = yaml.safe_load(f)
    config_parameters = config_yaml["parameters"]
    config_training_dict = {
        k: v.get("value") for k, v in config_parameters.items() if v is not None
    }
    config = DotMap(config_training_dict)
    config.IMAGE_HEIGHT = height
    config.IMAGE_WIDTH = width
depthPipeline = DepthPipeline(config, model="", device="cuda")

light_position = torch.randn((1,3))*config.DEPTH_SCALE_FACTOR/2
light_position[0,1:] = -torch.abs(light_position[0,1:])
torch.cuda.empty_cache()
with torch.no_grad():
    depth_map = depthPipeline.depth(batch["rgb"].cuda())

# Call with point light
result = reflection_warp.forward_point_light(
    source_image=batch["rgb"][0:1].cuda(),
    depth_map=depth_map[0:1].cuda(),
    camera_intrinsics=batch["intrinsics"].cuda()[0:1],
    camera_pose=torch.eye(4)
    .unsqueeze(0)
    .repeat(batch["rgb"].shape[0], 1, 1)
    .cuda()[0:1],
    light_position=light_position.cuda(),
    light_intensity=100.0,
    light_color=light_color.cuda(),
    surface_roughness=0.1,  # Slightly rough surface
    reflection_strength=0.9,  # Strong reflections
    return_mask=True,
    return_artifacts=True,
)
rgb(
    panelize(
        rgb(result["warped"][0], as_tensor=True),
        rgb(result["reflection_only"][0], colormap="gray", as_tensor=True),
        rgb(batch["rgb"][0], as_tensor=True),
    )
)

# %%
result.keys()

# %%
batch["rgb"].shape,depth_map.shape, batch["intrinsics"].shape,torch.eye(4).unsqueeze(0).repeat(batch["rgb"].shape[0],1,1).cuda().shape

# %%
result = reflection_warp.forward_point_light(
    source_image=batch["rgb"][0:1].cuda(),
    depth_map=depth_map[0:1].cuda(),
    camera_intrinsics=batch["intrinsics"].cuda()[0:1],
    camera_pose=torch.eye(4)
    .unsqueeze(0)
    .repeat(batch["rgb"].shape[0], 1, 1)
    .cuda()[0:1],
    light_position=light_position.cuda(),
    light_intensity=100.0,
    light_color=light_color.cuda(),
    surface_roughness=0.1,  # Slightly rough surface
    reflection_strength=0.9,  # Strong reflections
    return_mask=True,
    return_artifacts=True,
)

# %%
rgb(batch["rgb"][0])
rgb(depth_map[0],colormap="jet")
