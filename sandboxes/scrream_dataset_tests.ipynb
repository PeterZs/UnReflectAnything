# %%
import sys


sys.path.append("../../UnReflectAnything/")
from dataset.rgbp import HOUSECAT6D_Dataset
import torch
import yaml
from dotmap import DotMap

from pipelines.depth.depth import DepthPipeline
from projections import ReflectionWarp

### Load config
CONFIG_PATH = "../config.yaml"

with open(CONFIG_PATH, "r") as f:
    config_yaml = yaml.safe_load(f)
    config_parameters = config_yaml["parameters"]
    config_training_dict = {
        k: v.get("value") for k, v in config_parameters.items() if v is not None
    }
    config = DotMap(config_training_dict)

### Load depth estimation
depthPipeline = DepthPipeline(config, model="", device="cuda")
reflection_warp = ReflectionWarp(config.IMAGE_HEIGHT, config.IMAGE_WIDTH)
reflection_warp = reflection_warp.cuda()  # Move to GPU
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 10
#       7 import yaml
#       8 from dotmap import DotMap
# ---> 10 from pipelines.depth.depth import DepthPipeline
#      11 from projections import ReflectionWarp
#      13 ### Load config
#
# File ~/UnReflectAnything/sandboxes/../../UnReflectAnything/pipelines/__init__.py:1
# ----> 1 from . import depth, features, matching, odometry
#
# File ~/UnReflectAnything/sandboxes/../../UnReflectAnything/pipelines/depth/__init__.py:1
# ----> 1 from .depth import DepthPipeline
#       2 from .tsdf import TSDistanceFeatureColorVolume
#       4 __all__ = ["DepthPipeline", "TSDistanceFeatureColorVolume"]
#
# File ~/UnReflectAnything/sandboxes/../../UnReflectAnything/pipelines/depth/depth.py:15
#      11 from .tsdf import TSDistanceFeatureColorVolume
#      13 torch.autograd.set_detect_anomaly(True)
# ...

# %%
### Load dataset
dataset = HOUSECAT6D_Dataset(
    root_dir="$WORK/datasets/HouseCat6D/",
    # scene_names=["scene01_full_00"],
    rho_s=0.6,
    eps=1e-8,
)

# # Create dataloader
dataloader = torch.utils.data.DataLoader(
    dataset, batch_size=8, shuffle=True, num_workers=8
)

import time

# Measure batch loading time
batch_times = []
num_batches_to_test = 10

for i, sample in enumerate(dataloader):
    end_time = time.time()
    
    if i >= num_batches_to_test:
        break
    
    if i > 0:
        batch_time = end_time - start_time
        batch_times.append(batch_time)
    start_time = time.time()

# Calculate average batch loading time
avg_batch_time = sum(batch_times) / len(batch_times)
print(f"\nAverage batch loading time: {avg_batch_time:.4f}s")
print(f"Estimated time per sample: {avg_batch_time / dataloader.batch_size:.4f}s")
# Out:
# Average batch loading time: 0.2888s
# Estimated time per sample: 0.0361s

# %%
### Load dataset
dataset = HOUSECAT6D_Dataset(
    root_dir="/anvme/workspace/v120bb18-unreflectanything/datasets/HouseCat6D/",
    # scene_names=["scene01_full_00"],
    rho_s=0.6,
    eps=1e-8,
)

# # Create dataloader
dataloader = torch.utils.data.DataLoader(
    dataset, batch_size=8, shuffle=True, num_workers=8
)

import time

# Measure batch loading time
batch_times = []
num_batches_to_test = 10

for i, sample in enumerate(dataloader):
    end_time = time.time()
    
    if i >= num_batches_to_test:
        break
    
    if i > 0:
        batch_time = end_time - start_time
        batch_times.append(batch_time)
    start_time = time.time()

# Calculate average batch loading time
avg_batch_time = sum(batch_times) / len(batch_times)
print(f"\nAverage batch loading time: {avg_batch_time:.4f}s")
print(f"Estimated time per sample: {avg_batch_time / dataloader.batch_size:.4f}s")
# Out:
# Average batch loading time: 0.5243s
# Estimated time per sample: 0.0655s

# %%
from tqdm.notebook import tqdm

samplesizes = []
for sample in tqdm(dataloader):
    samplesizes.append(sample["rgb"].shape[2:])
# Out:
#   0%|          | 0/2055 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from tqdm.notebook import  tqdm
#       2 samplesizes = []
# ----> 3 for sample in tqdm(dataloader):
#       4     samplesizes.append(sample["rgb"].shape[2:])
#
# File ~/UnReflectAnything/.venv/lib/python3.10/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/UnReflectAnything/.venv/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
# ...

# %%
samplesizes = [torch.tensor(s) for s in samplesizes]
torch.stack(samplesizes).unique(dim=0)
# Out:
# tensor([[ 874, 1132]])
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
