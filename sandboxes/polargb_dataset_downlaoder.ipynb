# %%
from huggingface_hub import snapshot_download

# This downloads the full repo locally under /datasets/polargb
local_dir = snapshot_download(
    repo_id="Mingde/PolaRGB",
    repo_type="dataset",
    local_dir="/datasets/polargb"
)

print("Dataset stored at:", local_dir)
# Out:
# raw/train/easy/input/02/0009.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0013.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0014.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0012.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0010.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0008.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0011.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/02/0016.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/03/0000.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/03/0001.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/03/0002.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# raw/train/easy/input/03/0003.Bmp:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# ...
