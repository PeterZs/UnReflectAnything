# %%
import sys

sys.path.append("/home/atuin/v120bb/v120bb18/UnReflectAnything")

import torch
import matplotlib.pyplot as plt
import numpy as np
from torchvision import transforms

from PIL import Image
from utilities import panelize, rgb
from main import load_and_process_config, create_model_from_config,create_datasets_from_config
from dataset import from_config
from engine import Engine
# Load autoreload for development
# %load_ext autoreload
# %autoreload 2    
DEVICE = torch.device("cuda")

# %%
config = load_and_process_config("config_train.yaml")
config.BATCH_SIZE = 2
config.WARMUP = 0
model = create_model_from_config(config, DEVICE)

# Create datasets for training
dataset = create_datasets_from_config(config)

engine = Engine(
    model=model,  # Pass the created model
    dataset=dataset,
    config=config,
    no_wandb=True,
    notes=config.get("NOTES", ""),
)
# Out:
# MODEL    [22:09:37] Loaded pre-trained decoder weights from weights/rgb_decoder.pth
# MODEL    [22:09:38] Model with class UnReflect_Model_TokenInpainter created with 508,292,932 parameters
# DATASET  [22:09:38] Processing 1 datasets: ['SCARED']
# DATASET  [22:09:38] Using dataset-specific TRAIN_SCENES for SCARED: ['v16']
# DATASET  [22:09:38]   ✓ Created training dataset for SCARED: 1 samples from specific scenes
# DATASET  [22:09:38]   ✓ Created validation dataset for SCARED: 1 samples from 1 scenes
# DATASET  [22:09:38] === Dataset Creation Summary ===
# DATASET  [22:09:38] Training:   1 total samples
# DATASET  [22:09:38] Validation: 1 total samples
# DATASET  [22:09:38] Test:       1 total samples
# SAVE     [22:09:38]  Run directory: /anvme/workspace/v120bb18-unreflectanything/results/offline_20251104_220938

# %%
for e in range(100):
    engine.train()
